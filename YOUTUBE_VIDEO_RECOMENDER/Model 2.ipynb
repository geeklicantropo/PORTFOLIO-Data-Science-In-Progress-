# %% [markdown]
# <h1>A second model</h1>
# <p>After creating a initial model that fits the baseline, we want to create another model to beat the baseline.</p>

# %% [markdown]
# <h5>Importing the libraries</h5>
# <p>Just like before, we are importing the libraries.</p>

# %%
import pandas as pd
import numpy as np
import re
import time

import bs4 as bs4
import json

import glob
import tqdm

pd.set_option("max.columns", 131)

#https://strftime.org/
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <p>We are reading the CSV file and another non null column was created and named "y". That's our target variable.</p>

# %%
df = pd.read_csv("raw_data_with_labels.csv", index_col=0)
df = df[df['y'].notnull()]
df.shape
# Out:
# (498, 16)

# %%
df_limpo = pd.DataFrame(index=df.index)

# %% [markdown]
# <h1>Data Cleaning</h1>
# <p>Same as before. No changes here.</p>

# %%
clean_date = df['watch-time-text'].str.extract(r"(\d+) de ([a-z]+)\. de (\d+)")

# %%
clean_date[0] = clean_date[0].map(lambda x: "0"+x[0] if len(x) == 1 else x)

# %%
'''
It worked.
'''
clean_date[0]
# Out:
# 0      03
# 1      16
# 2      02
# 3      13
# 4      30
#        ..
# 496    01
# 497    31
# 498    10
# 499    25
# 500    21
# Name: 0, Length: 498, dtype: object

# %%
mapa_meses = {"jan": "Jan",
              "fev": "Feb",
              "mar": "Mar", 
              "abr": "Apr", 
              "mai": "May", 
              "jun": "Jun",
              "jul": "Jul",
              "ago": "Aug", 
              "set": "Sep", 
              "out": "Oct", 
              "nov": "Nov",
              "dez": "Dec"}

clean_date[1] = clean_date[1].map(mapa_meses)

# %%
clean_date[1]
# Out:
# 0      Sep
# 1      Nov
# 2      May
# 3      Aug
# 4      Nov
#       ...
# 496    Mar
# 497    May
# 498    Nov
# 499    Apr
# 500    Mar
# Name: 1, Length: 498, dtype: object

# %%
clean_date = clean_date.apply(lambda x: " ".join(x), axis=1)

df_limpo['date'] = pd.to_datetime(clean_date, format="%d %b %Y")

# %% [markdown]
# <h1>View Cleaning</h1>
# <p>Again, cleaning the views using the same old regular expression. No changes here either.</p>

# %%
views = df['watch-view-count'].str.extract(r"(\d+\.?\d*)", expand=False).str.replace(".", "").fillna(0).astype(int)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_10664/2268995852.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   views = df['watch-view-count'].str.extract(r"(\d+\.?\d*)", expand=False).str.replace(".", "").fillna(0).astype(int)

# %%
df_limpo['views'] = views

# %% [markdown]
# <h1>Creating Views</h1>
# <p>The process of creating views is the same as before.</p>

# %%
features = pd.DataFrame(index=df_limpo.index)
y = df['y'].copy()

# %% [markdown]
# <h5>Cleaning the date type</h5>

# %%
pd.to_datetime("2021-01-01") - df_limpo["date"]
# Out:
# 0      851 days
# 1      777 days
# 2      610 days
# 3      507 days
# 4      763 days
#          ...
# 496   1037 days
# 497    946 days
# 498    418 days
# 499    617 days
# 500    652 days
# Name: date, Length: 498, dtype: timedelta64[ns]

# %%
features['time_since_pub'] = (pd.to_datetime("2021-01-01") - df_limpo['date']) / np.timedelta64(1, 'D')

# %%
features['time_since_pub'].head()
# Out:
# 0    851.0
# 1    777.0
# 2    610.0
# 3    507.0
# 4    763.0
# Name: time_since_pub, dtype: float64

# %% [markdown]
# <h5>Cleaning the views</h5>

# %%
features['views'] = df_limpo['views']

# %%
features['views_per_day'] = features['views'] / features['time_since_pub']

# %%
features = features.drop(['time_since_pub'], axis=1)

# %%
features.head()
# Out:
#    views  views_per_day
# 0  28028      32.935370
# 1   1131       1.455598
# 2   1816       2.977049
# 3   1171       2.309665
# 4   1228       1.609436

# %% [markdown]
# <h1>Creating some variables to our model</h1>
# <p>Now we are gonna create some variables to use in our new model. Then, we are going to create the train and test variables, as always.</p>

# %%
mask_train = df_limpo['date'] < "2019-04-01"
mask_val = df_limpo['date'] >= "2019-04-01"

Xtrain, Xval = features[mask_train], features[mask_val]
ytrain, yval = y[mask_train], y[mask_val]
Xtrain.shape, Xval.shape, ytrain.shape, yval.shape
# Out:
# ((228, 2), (270, 2), (228,), (270,))

# %% [markdown]
# <h1>Turn strings into numbers</h1>
# <p>Our models can only understand numbers, not strings. And the column "title" only has words on it. To solve this problem, we can create a matrix wich counts how many times a word appears. Then we can create a column with each word and the counting in each line of dataframe. To do that we use the "TfidfVectorizer" library</p>
#
# <p>TfidfVectorizer is a library that gives more weight to words that appears too little in all the videos but too much in a single video. The "min_df" parameter dictates in how many videos a word must appear at minimum. We can adjust that number at will, but by doing this, it will affect the model's performance.</p>
#
# <h5>Sparcity of the matrix</h5>
# <p>By default, the vectorizer give us a sparse matrix, for optmization purposes. Meaning that we will only store values != 0. This is a way to conserve memory without allocating unnecessary resources to store unnecessary values.</p>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

df_limpo['title'] = df['watch-title']

title_train = df_limpo[mask_train]['title']
title_val = df_limpo[mask_val]['title']

#Title Bow is a bag of words
title_vec = TfidfVectorizer(min_df=2)
title_bow_train = title_vec.fit_transform(title_train)
title_bow_val = title_vec.transform(title_val)

# %%
title_bow_train
# Out:
# <228x193 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1277 stored elements in Compressed Sparse Row format>

# %%
title_bow_val
# Out:
# <270x193 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1266 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <p>We have a matrix of 228 by 193. Meaning, our total matrix space, counting the zeroes is 228*193.</p>

# %%
title_bow_train.shape
# Out:
# (228, 193)

# %%
title_bow_train
# Out:
# <228x193 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1277 stored elements in Compressed Sparse Row format>

# %% [markdown]
# <p>Almost all the dataframe (97%) is composed of zeroes. In order to preserve memory, we don't need to store the zeroes.</p>

# %%
1 - 1277/(228*193)
# Out:
# 0.9709799109171894

# %% [markdown]
# <h5>Joining some matrices</h5>
# <p>To join some matrices, we can use the "hstack" library from "scipy.sparse". There are 2 ways to join matrices. One way is through hstack, another through vstack. The differences between them can be seen down below. </p>

# %%
'''
hstack - [1 2]     [3 4]   -> [1 2 3 4] - 1x4

vstack - [1 2]     [3 4]   -> [1 2]
                              [3 4] - 2x2
'''
# Out:
# '\nhstack - [1 2]     [3 4]   -> [1 2 3 4] - 1x4\n\nvstack - [1 2]     [3 4]   -> [1 2]\n                              [3 4] - 2x2\n'

# %%
#Effectvily joining matrices
from scipy.sparse import hstack, vstack

Xtrain_wtitle = hstack([Xtrain, title_bow_train])
Xval_wtitle = hstack([Xval, title_bow_val])

# %%
Xtrain_wtitle.shape, Xval_wtitle.shape
# Out:
# ((228, 195), (270, 195))

# %% [markdown]
# <h1>Creating a model with Random Forest</h1>
# <p>In order to beat the scores in our baseline, now we are going to use the Random Forest algorithm.</p>

# %%
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

mdl = RandomForestClassifier(n_estimators=1000, random_state=0, class_weight="balanced", n_jobs=6)
mdl.fit(Xtrain_wtitle, ytrain)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=1000, n_jobs=6,
#                        random_state=0)

# %% [markdown]
# <h5>Verifying the results</h5>
# <p>After the training we are going to analyse the results with the "roc_auc_score" and the "average_precision_score". </p>

# %%
from sklearn.metrics import roc_auc_score, average_precision_score

# %%
p = mdl.predict_proba(Xval_wtitle)[:, 1]

# %%
average_precision_score(yval, p)
# Out:
# 0.18367911080129234

# %%
roc_auc_score(yval, p)
# Out:
# 0.5761094224924012

# %% [markdown]
# <h1>Conclusion</h1>
# <p>We have a higher precision score but a lower auc_roc_score. So, we can not conclude anything. We need both the metrics to be higher than our baseline.</p>

# %% [markdown]
# <h1>Active Learning</h1>
# <p>Sometimes we need to do more with less. Sometimes we don't have or can't have enough data to work with. Even so, we need to get as much information as we can off of the very few data we have. In order to do that, we use the Active Learning.</p>
# <p>For instance, if we have a hundred examples in wich our model can work with, we could choose 70 of these examples in wich the model can't perform well and 30 random examples.  </p>

# %% [markdown]
# <h5>Monving on</h5>
# <p>For now on, i will follow along the code with just enough comments. Mainlly because the process repeats itself in many steps.</p>

# %%
df_unlabeled = pd.read_csv("raw_data_with_labels.csv", index_col=0)
df_unlabeled = df_unlabeled[df_unlabeled['y'].isnull()].dropna(how='all')
df_unlabeled.shape
# Out:
# (674, 16)

# %%
df_unlabeled.head(1)
# Out:
#                                            watch-title   y  \
# 501  Kaggle Mercari Price Suggestion Challenge (1 p... NaN
#
#         watch-view-count                 watch-time-text  \
# 501  2.167 visualizações  Publicado em 2 de nov. de 2018
#
#     content_watch-info-tag-list  \
# 501                    Educação
#
#                                        watch7-headline  \
# 501  Kaggle Mercari Price Suggestion Challenge (1 p...
#
#                                     watch7-user-header  \
# 501  ML Trainings\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
#
#                               watch8-sentiment-actions  \
# 501  2.167 visualizações\n\n\n\n\n\n\n\n61\n\nGosto...
#
#                                               og:image  og:image:width  \
# 501  https://i.ytimg.com/vi/QFR0IHbzA30/maxresdefau...          1280.0
#
#      og:image:height                                     og:description  \
# 501            720.0  Pawel Jankiewicz and Konstantin Lopuhin share ...
#
#      og:video:width  og:video:height      og:video:tag  \
# 501          1280.0            720.0  price suggestion
#
#                         channel_link_0
# 501  /channel/UCeq6ZIlvC9SVsfhfKnSvM9w

# %%
df_limpo_u = pd.DataFrame(index=df_unlabeled.index)
df_limpo_u['title'] = df_unlabeled['watch-title']

# %%
clean_date = df_unlabeled['watch-time-text'].str.extract(r"(\d+) de ([a-z]+)\. de (\d+)")
clean_date[0] = clean_date[0].map(lambda x: "0"+x[0] if len(x) == 1 else x)
#clean_date[1] = clean_date[1].map(lambda x: x[0].upper()+x[1:])

mapa_meses = {"jan": "Jan",
              "fev": "Feb",
              "mar": "Mar", 
              "abr": "Apr", 
              "mai": "May", 
              "jun": "Jun",
              "jul": "Jul",
              "ago": "Aug", 
              "set": "Sep", 
              "out": "Oct", 
              "nov": "Nov",
              "dez": "Dec"}

clean_date[1] = clean_date[1].map(mapa_meses)

clean_date = clean_date.apply(lambda x: " ".join(x), axis=1)
clean_date.head()
df_limpo_u['date'] = pd.to_datetime(clean_date, format="%d %b %Y")

# %%
df_limpo_u.head()
# Out:
#                                                  title       date
# 501  Kaggle Mercari Price Suggestion Challenge (1 p... 2018-11-02
# 502  OpenAI Gym and Python for Q-learning - Reinfor... 2018-10-14
# 503  Dashboarding with Notebooks, Day 1: What infor... 2018-12-17
# 504  How To Get US- American Company H1 Visa To Get... 2019-11-23
# 505               Platform Overview - Machine Learning 2019-05-21

# %%
views = df_unlabeled['watch-view-count'].str.extract(r"(\d+\.?\d*)", expand=False).str.replace(".", "").fillna(0).astype(int)
df_limpo_u['views'] = views
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_10664/1255189512.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   views = df_unlabeled['watch-view-count'].str.extract(r"(\d+\.?\d*)", expand=False).str.replace(".", "").fillna(0).astype(int)

# %%
features_u = pd.DataFrame(index=df_limpo_u.index)

# %%
features_u['time_since_pub'] = (pd.to_datetime("2019-12-03") - df_limpo_u['date']) / np.timedelta64(1, 'D')
features_u['views'] = df_limpo_u['views']
features_u['views_per_day'] = features_u['views'] / features_u['time_since_pub']
features_u = features_u.drop(['time_since_pub'], axis=1)

# %%
features_u.head()
# Out:
#      views  views_per_day
# 501   2167       5.472222
# 502  20378      49.103614
# 503  10435      29.729345
# 504      7       0.700000
# 505   4298      21.928571

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

title_u = df_limpo_u['title']
title_bow_u = title_vec.transform(title_u)

# %%
title_bow_u
# Out:
# <674x193 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3079 stored elements in Compressed Sparse Row format>

# %%
Xu_wtitle = hstack([features_u, title_bow_u])

# %%
Xu_wtitle
# Out:
# <674x195 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4409 stored elements in COOrdinate format>

# %%
pu = mdl.predict_proba(Xu_wtitle)[:, 1]

# %%
df_unlabeled['probability_liking_video'] = pu

# %%
df_unlabeled.head(1)
# Out:
#                                            watch-title   y  \
# 501  Kaggle Mercari Price Suggestion Challenge (1 p... NaN
#
#         watch-view-count                 watch-time-text  \
# 501  2.167 visualizações  Publicado em 2 de nov. de 2018
#
#     content_watch-info-tag-list  \
# 501                    Educação
#
#                                        watch7-headline  \
# 501  Kaggle Mercari Price Suggestion Challenge (1 p...
#
#                                     watch7-user-header  \
# 501  ML Trainings\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
#
#                               watch8-sentiment-actions  \
# 501  2.167 visualizações\n\n\n\n\n\n\n\n61\n\nGosto...
#
#                                               og:image  og:image:width  \
# 501  https://i.ytimg.com/vi/QFR0IHbzA30/maxresdefau...          1280.0
#
#      og:image:height                                     og:description  \
# 501            720.0  Pawel Jankiewicz and Konstantin Lopuhin share ...
#
#      og:video:width  og:video:height      og:video:tag  \
# 501          1280.0            720.0  price suggestion
#
#                         channel_link_0  probability_liking_video
# 501  /channel/UCeq6ZIlvC9SVsfhfKnSvM9w                     0.107

# %%
mask_u = (df_unlabeled['probability_liking_video'] >= 0.26) & (df_unlabeled['probability_liking_video'] <= 1.)
mask_u.sum()
# Out:
# 72

# %%
mask_u
# Out:
# 501     False
# 502     False
# 503     False
# 504     False
# 505      True
#         ...
# 1179    False
# 1180    False
# 1181    False
# 1182    False
# 1183    False
# Name: probability_liking_video, Length: 674, dtype: bool

# %%
df_unlabeled[mask_u]
# Out:
#                                             watch-title   y  \
# 505                Platform Overview - Machine Learning NaN
# 507             Kaggle Meetup: Ship Detection Challenge NaN
# 521   Kaggle iMaterialist (Fashion) 2019 at FGVC6 — ... NaN
# 522   Anomaly detection using machine learning in Az... NaN
# 527   Reinforcement Learning with TensorFlow and Uni... NaN
# ...                                                 ...  ..
# 1114  Artificial Intelligence & Machine Learning  - ... NaN
# 1120  Recognizing Students at Risk of Dropping Out -... NaN
# 1136  Real Stories from Career Switchers | CareerCon... NaN
# 1138  NIPS 2017 Test of Time Award "Machine learning... NaN
# 1176  Using Google's Data and AI Technologies with K... NaN
#
#           watch-view-count                  watch-time-text  \
# 505    4.298 visualizações  Publicado em 21 de mai. de 2019
# 507      504 visualizações  Publicado em 30 de nov. de 2018
# 521      526 visualizações  Publicado em 18 de set. de 2019
# 522    2.570 visualizações  Publicado em 13 de fev. de 2019
# 527      545 visualizações  Publicado em 22 de nov. de 2019
# ...                    ...                              ...
# 1114      28 visualizações  Publicado em 25 de nov. de 2019
# 1120       5 visualizações  Publicado em 24 de nov. de 2019
# 1136     531 visualizações  Publicado em 15 de ago. de 2019
# 1138  13.474 visualizações   Publicado em 7 de mar. de 2018
# 1176     727 visualizações  Publicado em 24 de abr. de 2019
#
#                             content_watch-info-tag-list  \
# 505                                Ciência e tecnologia
# 507                                Ciência e tecnologia
# 521                                            Educação
# 522                                Ciência e tecnologia
# 527                                Ciência e tecnologia
# ...                                                 ...
# 1114                                           Educação
# 1120  SME, WMG (em nome de WM Spain); LatinAutor, CM...
# 1136                               Ciência e tecnologia
# 1138                                           Educação
# 1176                               Ciência e tecnologia
#
#                                         watch7-headline  \
# 505                Platform Overview - Machine Learning
# 507             Kaggle Meetup: Ship Detection Challenge
# 521   Kaggle iMaterialist (Fashion) 2019 at FGVC6 — ...
# 522   #azure #azurestreamanalytics #machinelearning\...
# 527   Reinforcement Learning with TensorFlow and Uni...
# ...                                                 ...
# 1114  Artificial Intelligence & Machine Learning  - ...
# 1120  Recognizing Students at Risk of Dropping Out -...
# 1136  Real Stories from Career Switchers | CareerCon...
# 1138  NIPS 2017 Test of Time Award "Machine learning...
# 1176  Using Google's Data and AI Technologies with K...
#
#                                      watch7-user-header  \
# 505   Google Cloud Platform\n\n\n\n\n\n\n\n\n\n\n\n\...
# 507   Learn Data Science\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 521   ML Trainings\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
# 522   Microsoft Developer\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 527   Google Developers\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                 ...
# 1114  jayanti prasad\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarr...
# 1120  Joe Spaeth\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregan...
# 1136  Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 1138  Preserve Knowledge\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1176  Google Cloud Platform\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                watch8-sentiment-actions  \
# 505   4.298 visualizações\n\n\n\n\n\n\n\n141\n\nGost...
# 507   504 visualizações\n\n\n\n\n\n\n\n9\n\nGostou d...
# 521   526 visualizações\n\n\n\n\n\n\n\n18\n\nGostou ...
# 522   2.570 visualizações\n\n\n\n\n\n\n\n32\n\nGosto...
# 527   545 visualizações\n\n\n\n\n\n\n\n13\n\nGostou ...
# ...                                                 ...
# 1114  28 visualizações\n\n\n\n\n\n\n\n1\n\nGostou de...
# 1120  5 visualizações\n\n\n\n\n\n\n\n0\n\nGostou des...
# 1136  531 visualizações\n\n\n\n\n\n\n\n24\n\nGostou ...
# 1138  13.474 visualizações\n\n\n\n\n\n\n\n138\n\nGos...
# 1176  727 visualizações\n\n\n\n\n\n\n\n17\n\nGostou ...
#
#                                                og:image  og:image:width  \
# 505   https://i.ytimg.com/vi/QR_LQQ-vvko/maxresdefau...          1280.0
# 507   https://i.ytimg.com/vi/QXEy4rdLsDw/maxresdefau...          1280.0
# 521   https://i.ytimg.com/vi/RUfmEj1MC3k/maxresdefau...          1280.0
# 522   https://i.ytimg.com/vi/Ra8HhBLdzHE/maxresdefau...          1280.0
# 527   https://i.ytimg.com/vi/S-MbpQiwfls/maxresdefau...          1280.0
# ...                                                 ...             ...
# 1114   https://i.ytimg.com/vi/vhnLdxH8eP0/hqdefault.jpg           480.0
# 1120  https://i.ytimg.com/vi/w104zCQNB38/maxresdefau...          1280.0
# 1136  https://i.ytimg.com/vi/wyU9GTKSO0g/maxresdefau...          1280.0
# 1138  https://i.ytimg.com/vi/x7psGHgatGM/maxresdefau...          1280.0
# 1176  https://i.ytimg.com/vi/zPR3upTfMSI/maxresdefau...          1280.0
#
#       og:image:height                                     og:description  \
# 505             720.0  In this short GCP Essentials video, see how GC...
# 507             720.0  Video from the 2018-11-29 meetup. Kaggle page:...
# 521             720.0  Илья Денисов рассказывает про опыт участия в с...
# 522             720.0  Azure Stream Analytics is a fully managed serv...
# 527             720.0  Dan Goncharov, Head of 42 Robotics GDG Fremont...
# ...               ...                                                ...
# 1114            360.0       A Review of machine learning on source code.
# 1120            720.0  ML4VA project by Anna Spearman, Noah Collins, ...
# 1136            720.0  "Listen to a panel of speakers who successfull...
# 1138            720.0
# 1176            720.0  Kaggle is the world's largest community of dat...
#
#       og:video:width  og:video:height               og:video:tag  \
# 505           1280.0            720.0  Alexis Moussine Pouchkine
# 507           1280.0            720.0         learn data science
# 521           1280.0            720.0                     kaggle
# 522           1280.0            720.0               Azure Friday
# 527           1280.0            720.0              Dan Goncharov
# ...              ...              ...                        ...
# 1114           960.0            720.0                        NaN
# 1120          1280.0            720.0                        NaN
# 1136          1280.0            720.0                  careercon
# 1138          1280.0            720.0                  NIPS 2017
# 1176          1280.0            720.0                   official
#
#                          channel_link_0  probability_liking_video
# 505   /channel/UCJS9pqu9BzkAMNTmzNMNhvg                     0.428
# 507   /channel/UCJhW_16uxALr0X4olEW2p5A                     0.387
# 521   /channel/UCeq6ZIlvC9SVsfhfKnSvM9w                     0.262
# 522   /channel/UCsMica-v34Irf9KVTh6xx-g                     0.261
# 527   /channel/UC_x5XG1OV2P6uZZ5FSM9Ttw                     0.276
# ...                                 ...                       ...
# 1114  /channel/UCJesxoOgwZS5JpHrTDOS-8A                     0.467
# 1120  /channel/UCZDNp9Zik3T8DjKzarPlDpQ                     0.345
# 1136  /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.459
# 1138  /channel/UC9p_wQs8b8SHvfJSuuxEnvw                     0.311
# 1176  /channel/UCJS9pqu9BzkAMNTmzNMNhvg                     0.267
#
# [72 rows x 17 columns]

# %%
hard_to_predict = df_unlabeled[mask_u]

# %%
random = df_unlabeled[~mask_u].sample(31, random_state=0)

# %%
pd.concat([hard_to_predict, random]).to_csv("active_label1.csv")

# %%
hard_to_predict
# Out:
#                                             watch-title   y  \
# 505                Platform Overview - Machine Learning NaN
# 507             Kaggle Meetup: Ship Detection Challenge NaN
# 521   Kaggle iMaterialist (Fashion) 2019 at FGVC6 — ... NaN
# 522   Anomaly detection using machine learning in Az... NaN
# 527   Reinforcement Learning with TensorFlow and Uni... NaN
# ...                                                 ...  ..
# 1114  Artificial Intelligence & Machine Learning  - ... NaN
# 1120  Recognizing Students at Risk of Dropping Out -... NaN
# 1136  Real Stories from Career Switchers | CareerCon... NaN
# 1138  NIPS 2017 Test of Time Award "Machine learning... NaN
# 1176  Using Google's Data and AI Technologies with K... NaN
#
#           watch-view-count                  watch-time-text  \
# 505    4.298 visualizações  Publicado em 21 de mai. de 2019
# 507      504 visualizações  Publicado em 30 de nov. de 2018
# 521      526 visualizações  Publicado em 18 de set. de 2019
# 522    2.570 visualizações  Publicado em 13 de fev. de 2019
# 527      545 visualizações  Publicado em 22 de nov. de 2019
# ...                    ...                              ...
# 1114      28 visualizações  Publicado em 25 de nov. de 2019
# 1120       5 visualizações  Publicado em 24 de nov. de 2019
# 1136     531 visualizações  Publicado em 15 de ago. de 2019
# 1138  13.474 visualizações   Publicado em 7 de mar. de 2018
# 1176     727 visualizações  Publicado em 24 de abr. de 2019
#
#                             content_watch-info-tag-list  \
# 505                                Ciência e tecnologia
# 507                                Ciência e tecnologia
# 521                                            Educação
# 522                                Ciência e tecnologia
# 527                                Ciência e tecnologia
# ...                                                 ...
# 1114                                           Educação
# 1120  SME, WMG (em nome de WM Spain); LatinAutor, CM...
# 1136                               Ciência e tecnologia
# 1138                                           Educação
# 1176                               Ciência e tecnologia
#
#                                         watch7-headline  \
# 505                Platform Overview - Machine Learning
# 507             Kaggle Meetup: Ship Detection Challenge
# 521   Kaggle iMaterialist (Fashion) 2019 at FGVC6 — ...
# 522   #azure #azurestreamanalytics #machinelearning\...
# 527   Reinforcement Learning with TensorFlow and Uni...
# ...                                                 ...
# 1114  Artificial Intelligence & Machine Learning  - ...
# 1120  Recognizing Students at Risk of Dropping Out -...
# 1136  Real Stories from Career Switchers | CareerCon...
# 1138  NIPS 2017 Test of Time Award "Machine learning...
# 1176  Using Google's Data and AI Technologies with K...
#
#                                      watch7-user-header  \
# 505   Google Cloud Platform\n\n\n\n\n\n\n\n\n\n\n\n\...
# 507   Learn Data Science\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 521   ML Trainings\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
# 522   Microsoft Developer\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 527   Google Developers\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                 ...
# 1114  jayanti prasad\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarr...
# 1120  Joe Spaeth\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregan...
# 1136  Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 1138  Preserve Knowledge\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1176  Google Cloud Platform\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                watch8-sentiment-actions  \
# 505   4.298 visualizações\n\n\n\n\n\n\n\n141\n\nGost...
# 507   504 visualizações\n\n\n\n\n\n\n\n9\n\nGostou d...
# 521   526 visualizações\n\n\n\n\n\n\n\n18\n\nGostou ...
# 522   2.570 visualizações\n\n\n\n\n\n\n\n32\n\nGosto...
# 527   545 visualizações\n\n\n\n\n\n\n\n13\n\nGostou ...
# ...                                                 ...
# 1114  28 visualizações\n\n\n\n\n\n\n\n1\n\nGostou de...
# 1120  5 visualizações\n\n\n\n\n\n\n\n0\n\nGostou des...
# 1136  531 visualizações\n\n\n\n\n\n\n\n24\n\nGostou ...
# 1138  13.474 visualizações\n\n\n\n\n\n\n\n138\n\nGos...
# 1176  727 visualizações\n\n\n\n\n\n\n\n17\n\nGostou ...
#
#                                                og:image  og:image:width  \
# 505   https://i.ytimg.com/vi/QR_LQQ-vvko/maxresdefau...          1280.0
# 507   https://i.ytimg.com/vi/QXEy4rdLsDw/maxresdefau...          1280.0
# 521   https://i.ytimg.com/vi/RUfmEj1MC3k/maxresdefau...          1280.0
# 522   https://i.ytimg.com/vi/Ra8HhBLdzHE/maxresdefau...          1280.0
# 527   https://i.ytimg.com/vi/S-MbpQiwfls/maxresdefau...          1280.0
# ...                                                 ...             ...
# 1114   https://i.ytimg.com/vi/vhnLdxH8eP0/hqdefault.jpg           480.0
# 1120  https://i.ytimg.com/vi/w104zCQNB38/maxresdefau...          1280.0
# 1136  https://i.ytimg.com/vi/wyU9GTKSO0g/maxresdefau...          1280.0
# 1138  https://i.ytimg.com/vi/x7psGHgatGM/maxresdefau...          1280.0
# 1176  https://i.ytimg.com/vi/zPR3upTfMSI/maxresdefau...          1280.0
#
#       og:image:height                                     og:description  \
# 505             720.0  In this short GCP Essentials video, see how GC...
# 507             720.0  Video from the 2018-11-29 meetup. Kaggle page:...
# 521             720.0  Илья Денисов рассказывает про опыт участия в с...
# 522             720.0  Azure Stream Analytics is a fully managed serv...
# 527             720.0  Dan Goncharov, Head of 42 Robotics GDG Fremont...
# ...               ...                                                ...
# 1114            360.0       A Review of machine learning on source code.
# 1120            720.0  ML4VA project by Anna Spearman, Noah Collins, ...
# 1136            720.0  "Listen to a panel of speakers who successfull...
# 1138            720.0
# 1176            720.0  Kaggle is the world's largest community of dat...
#
#       og:video:width  og:video:height               og:video:tag  \
# 505           1280.0            720.0  Alexis Moussine Pouchkine
# 507           1280.0            720.0         learn data science
# 521           1280.0            720.0                     kaggle
# 522           1280.0            720.0               Azure Friday
# 527           1280.0            720.0              Dan Goncharov
# ...              ...              ...                        ...
# 1114           960.0            720.0                        NaN
# 1120          1280.0            720.0                        NaN
# 1136          1280.0            720.0                  careercon
# 1138          1280.0            720.0                  NIPS 2017
# 1176          1280.0            720.0                   official
#
#                          channel_link_0  probability_liking_video
# 505   /channel/UCJS9pqu9BzkAMNTmzNMNhvg                     0.428
# 507   /channel/UCJhW_16uxALr0X4olEW2p5A                     0.387
# 521   /channel/UCeq6ZIlvC9SVsfhfKnSvM9w                     0.262
# 522   /channel/UCsMica-v34Irf9KVTh6xx-g                     0.261
# 527   /channel/UC_x5XG1OV2P6uZZ5FSM9Ttw                     0.276
# ...                                 ...                       ...
# 1114  /channel/UCJesxoOgwZS5JpHrTDOS-8A                     0.467
# 1120  /channel/UCZDNp9Zik3T8DjKzarPlDpQ                     0.345
# 1136  /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.459
# 1138  /channel/UC9p_wQs8b8SHvfJSuuxEnvw                     0.311
# 1176  /channel/UCJS9pqu9BzkAMNTmzNMNhvg                     0.267
#
# [72 rows x 17 columns]

# %%
random
# Out:
#                                             watch-title   y  \
# 809   Machine Learning for Pricing & Auctions - Tuto... NaN
# 560   Tableau for Data Science and Data Visualizatio... NaN
# 1045  How machine learning is being used to help sav... NaN
# 726   I Passed the Final Data Science Assignment! | ... NaN
# 891   Learn Data Science Today - Data Science Tutori... NaN
# 889   Kaggle Live Coding: Automating report generati... NaN
# 779   Code with me (live): How to make your first Ka... NaN
# 1037  Data Science Training  | Data Science for Begi... NaN
# 984             Checking out a Data Science Workstation NaN
# 902             Deep Learning VM Images (AI Adventures) NaN
# 563   TU Dublin Ireland - MSc Data Analytics - Arshd... NaN
# 916   DataFest - Павел Плесков (DataNerds.ai) - How ... NaN
# 975                           What is machine learning? NaN
# 1099       How Did I Learn Machine Learning in 3 Months NaN
# 717         Kaggle Livecoding: Error Analysis  | Kaggle NaN
# 725   Introduction to Forecasting in Machine Learnin... NaN
# 666   From Deep Learning of Disentangled Representat... NaN
# 1172               DATA SCIENCE BOOTCAMPS: GOOD OR BAD? NaN
# 570   #kaggle #DataScience Machine Learning MicroCou... NaN
# 903     Kaggle Elo Merchant Category Recommendation EDA NaN
# 739   Complete Machine Learning Fundamentals in less... NaN
# 907   Coding Challenge #147: Chrome Dinosaur Game (w... NaN
# 1000  Kaggle Solution for Titanic competition (Deep ... NaN
# 776   Kaggle Live Coding: Implementing Text Cluster ... NaN
# 1098                Como é ser data scientist no Nubank NaN
# 716   Why Deep Learning Now? | AI Revolution Documen... NaN
# 944   IoT and Machine Learning - Changing the Future... NaN
# 1165  Kaggle Reading Group: Bidirectional Encoder Re... NaN
# 766   Kaggle Live-Coding: Mapping the Data Science P... NaN
# 668   What is Deep Learning? (The Pattern Machine pa... NaN
# 797   Google "Machine Learning Fairness" Whistleblow... NaN
#
#              watch-view-count                            watch-time-text  \
# 809       3.867 visualizações            Publicado em 25 de jul. de 2018
# 560      87.049 visualizações            Publicado em 29 de jan. de 2019
# 1045  1.544.819 visualizações            Publicado em 24 de out. de 2019
# 726      11.421 visualizações            Publicado em 11 de nov. de 2018
# 891     178.094 visualizações            Publicado em 10 de jan. de 2019
# 889       1.725 visualizações  Transmitido ao vivo em 11 de out. de 2019
# 779      23.854 visualizações   Transmitido ao vivo em 1 de dez. de 2018
# 1037     47.046 visualizações            Publicado em 28 de set. de 2019
# 984     101.921 visualizações             Publicado em 5 de out. de 2019
# 902       9.505 visualizações            Publicado em 10 de out. de 2018
# 563      16.921 visualizações            Publicado em 14 de abr. de 2019
# 916       2.180 visualizações            Publicado em 21 de out. de 2018
# 975       1.041 visualizações            Publicado em 29 de jan. de 2019
# 1099     76.071 visualizações            Publicado em 18 de set. de 2019
# 717       2.147 visualizações  Transmitido ao vivo em 22 de nov. de 2019
# 725      32.910 visualizações             Publicado em 4 de mai. de 2018
# 666      37.182 visualizações             Publicado em 8 de fev. de 2018
# 1172     41.440 visualizações            Publicado em 21 de fev. de 2019
# 570         393 visualizações            Publicado em 26 de jul. de 2019
# 903         279 visualizações   Transmitido ao vivo em 6 de dez. de 2018
# 739       1.946 visualizações            Publicado em 22 de jul. de 2018
# 907     109.592 visualizações            Publicado em 18 de jun. de 2019
# 1000         21 visualizações            Publicado em 13 de out. de 2019
# 776       1.603 visualizações  Transmitido ao vivo em 30 de ago. de 2019
# 1098     48.035 visualizações            Publicado em 16 de jan. de 2019
# 716     301.145 visualizações            Publicado em 30 de out. de 2018
# 944      22.365 visualizações            Publicado em 10 de abr. de 2018
# 1165      1.797 visualizações  Transmitido ao vivo em 23 de jan. de 2019
# 766         688 visualizações   Transmitido ao vivo em 2 de nov. de 2018
# 668      17.793 visualizações            Publicado em 17 de mai. de 2019
# 797     660.801 visualizações            Publicado em 14 de ago. de 2019
#
#                             content_watch-info-tag-list  \
# 809                                Ciência e tecnologia
# 560                                            Educação
# 1045  Licença de atribuição Creative Commons (reutil...
# 726                                Ciência e tecnologia
# 891                                     Pessoas e blogs
# 889                                Ciência e tecnologia
# 779                                Ciência e tecnologia
# 1037                                           Educação
# 984                                            Educação
# 902                                Ciência e tecnologia
# 563                                            Educação
# 916                                     Pessoas e blogs
# 975                                Ciência e tecnologia
# 1099                                           Educação
# 717                                Ciência e tecnologia
# 725                                Ciência e tecnologia
# 666                                Ciência e tecnologia
# 1172                                     Entretenimento
# 570                                            Educação
# 903                                Ciência e tecnologia
# 739                                Ciência e tecnologia
# 907                                            Educação
# 1000                                           Educação
# 776                                Ciência e tecnologia
# 1098                               Ciência e tecnologia
# 716   Collab Asia Music e 1 associações de direitos ...
# 944                        Sem fins lucrativos/ativismo
# 1165                               Ciência e tecnologia
# 766                                Ciência e tecnologia
# 668                                            Educação
# 797                                 Notícias e política
#
#                                         watch7-headline  \
# 809   Machine Learning for Pricing & Auctions - Tuto...
# 560   Tableau for Data Science and Data Visualizatio...
# 1045  How machine learning is being used to help sav...
# 726   #datascience #machinelearning #artificialintel...
# 891   #DataScienceWithPython #DataScienceWithR #Data...
# 889   Kaggle Live Coding: Automating report generati...
# 779   #datascience #machinelearning #kaggle\n\n\n\n ...
# 1037  #DataScience #DataScienceTraining #DataScience...
# 984             Checking out a Data Science Workstation
# 902             Deep Learning VM Images (AI Adventures)
# 563   TU Dublin Ireland - MSc Data Analytics - Arshd...
# 916   DataFest - Павел Плесков (DataNerds.ai) - How ...
# 975                           What is machine learning?
# 1099       How Did I Learn Machine Learning in 3 Months
# 717         Kaggle Livecoding: Error Analysis  | Kaggle
# 725   Introduction to Forecasting in Machine Learnin...
# 666   From Deep Learning of Disentangled Representat...
# 1172               DATA SCIENCE BOOTCAMPS: GOOD OR BAD?
# 570   #kaggle #DataScience Machine Learning MicroCou...
# 903     Kaggle Elo Merchant Category Recommendation EDA
# 739   Complete Machine Learning Fundamentals in less...
# 907   Coding Challenge #147: Chrome Dinosaur Game (w...
# 1000  Kaggle Solution for Titanic competition (Deep ...
# 776   Kaggle Live Coding: Implementing Text Cluster ...
# 1098  #machinelearning #datascience\n\n\n\n    Como ...
# 716   Why Deep Learning Now? | AI Revolution Documen...
# 944   IoT and Machine Learning - Changing the Future...
# 1165  Kaggle Reading Group: Bidirectional Encoder Re...
# 766   Kaggle Live-Coding: Mapping the Data Science P...
# 668   What is Deep Learning? (The Pattern Machine pa...
# 797   Google "Machine Learning Fairness" Whistleblow...
#
#                                      watch7-user-header  \
# 809   The Artificial Intelligence Channel\n\n\n\n\n\...
# 560   freeCodeCamp.org\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1045  Google\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando...
# 726   Daniel Bourke\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarre...
# 891   UpDegree\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando...
# 889   Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 779   Daniel Bourke\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarre...
# 1037  Intellipaat\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarrega...
# 984   sentdex\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregand...
# 902   Google Cloud Platform\n\n\n\n\n\n\n\n\n\n\n\n\...
# 563   DubJobs\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando....
# 916   videoCFT\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando...
# 975   Australian Institute for Machine Learning\n\n\...
# 1099  Krish Naik\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregan...
# 717   Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 725   InfoQ\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando......
# 666   Microsoft Research\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1172  Python Programmer\n\n\n\n\n\n\n\n\n\n\n\n\n\nC...
# 570   danny iskandar\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarr...
# 903   Ryan Chesler\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
# 739   Rakesh Naga Chinta\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 907   The Coding Train\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1000  Manula Udugahapattuwa\n\n\n\n\n\n\n\n\n\n\n\n\...
# 776   Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 1098  Nubank\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando...
# 716   ColdFusion\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
# 944   TEDx Talks\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarreg...
# 1165  Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 766   Kaggle\n\n\n\n\n\n\n\n\n\n\n\n\n\nCarregando.....
# 668   Art of the Problem\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 797   Project Veritas\n\n\n\n\n\n\n\n\n\n\n\n\n\nCar...
#
#                                watch8-sentiment-actions  \
# 809   3.867 visualizações\n\n\n\n\n\n\n\n66\n\nGosto...
# 560   87.049 visualizações\n\n\n\n\n\n\n\n1.171\n\nG...
# 1045  1.544.819 visualizações\n\n\n\n\n\n\n\n4.615\n...
# 726   11.421 visualizações\n\n\n\n\n\n\n\n211\n\nGos...
# 891   178.094 visualizações\n\n\n\n\n\n\n\n6.112\n\n...
# 889   1.725 visualizações\n\n\n\n\n\n\n\n66\n\nGosto...
# 779   23.854 visualizações\n\n\n\n\n\n\n\n576\n\nGos...
# 1037  47.046 visualizações\n\n\n\n\n\n\n\n1.382\n\nG...
# 984   101.921 visualizações\n\n\n\n\n\n\n\n2.124\n\n...
# 902   9.505 visualizações\n\n\n\n\n\n\n\n211\n\nGost...
# 563   16.921 visualizações\n\n\n\n\n\n\n\n518\n\nGos...
# 916   2.180 visualizações\n\n\n\n\n\n\n\n60\n\nGosto...
# 975   1.041 visualizações\n\n\n\n\n\n\n\n11\n\nGosto...
# 1099  76.071 visualizações\n\n\n\n\n\n\n\n2.771\n\nG...
# 717   2.147 visualizações\n\n\n\n\n\n\n\n91\n\nGosto...
# 725   32.910 visualizações\n\n\n\n\n\n\n\n611\n\nGos...
# 666   37.182 visualizações\n\n\n\n\n\n\n\n809\n\nGos...
# 1172  41.440 visualizações\n\n\n\n\n\n\n\n1.172\n\nG...
# 570   393 visualizações\n\n\n\n\n\n\n\n14\n\nGostou ...
# 903   279 visualizações\n\n\n\n\n\n\n\n2\n\nGostou d...
# 739   1.946 visualizações\n\n\n\n\n\n\n\n29\n\nGosto...
# 907   109.592 visualizações\n\n\n\n\n\n\n\n3.196\n\n...
# 1000  21 visualizações\n\n\n\n\n\n\n\n1\n\nGostou de...
# 776   1.603 visualizações\n\n\n\n\n\n\n\n41\n\nGosto...
# 1098  48.035 visualizações\n\n\n\n\n\n\n\n2.908\n\nG...
# 716   301.145 visualizações\n\n\n\n\n\n\n\n12.528\n\...
# 944   22.365 visualizações\n\n\n\n\n\n\n\n266\n\nGos...
# 1165  1.797 visualizações\n\n\n\n\n\n\n\n44\n\nGosto...
# 766   688 visualizações\n\n\n\n\n\n\n\n11\n\nGostou ...
# 668   17.793 visualizações\n\n\n\n\n\n\n\n781\n\nGos...
# 797   660.801 visualizações\n\n\n\n\n\n\n\n54.837\n\...
#
#                                                og:image  og:image:width  \
# 809   https://i.ytimg.com/vi/gsPWQqVhb74/maxresdefau...          1280.0
# 560   https://i.ytimg.com/vi/TPMlZxRRaBQ/maxresdefau...          1280.0
# 1045  https://i.ytimg.com/vi/sgCGHBek1To/maxresdefau...          1280.0
# 726   https://i.ytimg.com/vi/btjp5PE96Sw/maxresdefau...          1280.0
# 891   https://i.ytimg.com/vi/kE9875zZkLE/maxresdefau...          1280.0
# 889    https://i.ytimg.com/vi/kDzEZihQFig/hqdefault.jpg           480.0
# 779    https://i.ytimg.com/vi/f1y9wDDxWnA/hqdefault.jpg           480.0
# 1037  https://i.ytimg.com/vi/sEtQUnVA4wQ/maxresdefau...          1280.0
# 984   https://i.ytimg.com/vi/p9bkz3hxrSM/maxresdefau...          1280.0
# 902   https://i.ytimg.com/vi/kyNbYCHFCSw/maxresdefau...          1280.0
# 563   https://i.ytimg.com/vi/TVFpKvswngo/maxresdefau...          1280.0
# 916   https://i.ytimg.com/vi/leD0agQkO9s/maxresdefau...          1280.0
# 975   https://i.ytimg.com/vi/ob_p9qARjJo/maxresdefau...          1280.0
# 1099   https://i.ytimg.com/vi/uoifG7TgF2k/hqdefault.jpg           480.0
# 717    https://i.ytimg.com/vi/b9aPrCAAJeM/hqdefault.jpg           480.0
# 725   https://i.ytimg.com/vi/bn8rVBuIcFg/maxresdefau...          1280.0
# 666   https://i.ytimg.com/vi/Yr1mOzC93xs/maxresdefau...          1280.0
# 1172  https://i.ytimg.com/vi/zLSpuOWwmvE/maxresdefau...          1280.0
# 570   https://i.ytimg.com/vi/U-ahlu_Nxa0/maxresdefau...          1280.0
# 903    https://i.ytimg.com/vi/kzh_XMBc7eI/hqdefault.jpg           480.0
# 739   https://i.ytimg.com/vi/cVyRds9GF0w/maxresdefau...          1280.0
# 907   https://i.ytimg.com/vi/l0HoJHc-63Q/maxresdefau...          1280.0
# 1000   https://i.ytimg.com/vi/qBrFnxCXC6c/hqdefault.jpg           480.0
# 776    https://i.ytimg.com/vi/esX3RuAhgFE/hqdefault.jpg           480.0
# 1098  https://i.ytimg.com/vi/umq9kCJFavw/maxresdefau...          1280.0
# 716   https://i.ytimg.com/vi/b3IyDNB_ciI/maxresdefau...          1280.0
# 944   https://i.ytimg.com/vi/mlE03Fj2T9s/maxresdefau...          1280.0
# 1165  https://i.ytimg.com/vi/yqwnehmB9uQ/maxresdefau...          1280.0
# 766   https://i.ytimg.com/vi/eNKXJwIOsnc/maxresdefau...          1280.0
# 668    https://i.ytimg.com/vi/YulgDAaHBKw/hqdefault.jpg           480.0
# 797   https://i.ytimg.com/vi/g1VeElBAeas/maxresdefau...          1280.0
#
#       og:image:height                                     og:description  \
# 809             720.0  Recorded July 10th, 2018 This tutorial Machine...
# 560             720.0  Learn to use Tableau to produce high quality, ...
# 1045            720.0  Bee populations around the world are declining...
# 726             720.0  Woohoo! I passed one of the hardest assignment...
# 891             720.0  This Data Science Course will give you a Step ...
# 889             360.0  This week Rachael will continue to work on her...
# 779             360.0  Let's explore some Kaggle data together! Thank...
# 1037            720.0  🔥Intellipaat Data Science training course usin...
# 984             720.0  Checking out Lenovo's top of the line P920 Dat...
# 902             720.0  Imagine if you could avoid the headache of set...
# 563             720.0  Book your university course with DubJobs: http...
# 916             720.0  Data Fest Siberia - первая Data Science конфер...
# 975             720.0
# 1099            360.0  Please join as a member in my channel to get a...
# 717             360.0  This week we'll be working on some error analy...
# 725             720.0  Are you enthusiastic about sharing your knowle...
# 666             720.0  One of the main challenges for AI remains unsu...
# 1172            720.0  My opinion on Data Science Bootcamps. Free boo...
# 570             720.0  Deep Dive into Machine Learning MicroCourse Pa...
# 903             360.0  Starting to work on the Kaggle Elo Merchant Ca...
# 739             720.0  I am Rakesh Naga Chinta, a Data science + Busi...
# 907             720.0  In this challenge, I attempt to make my own ve...
# 1000            360.0  This explanation goes through thorough data vi...
# 776             360.0  This week we'll be implementing some text clus...
# 1098            720.0  Um dos grandes diferencias do Nubank é que tod...
# 716             720.0  Learn more: https://developer.movidius.com/ ht...
# 944             720.0  Dr. Dennis Ong is a Technology Evangelist. Dr....
# 1165            720.0  Join Kaggle Data Scientist Rachael as she read...
# 766             720.0  Join Kaggle data scientist Rachael live as she...
# 668             360.0  Introduces the key ideas behind Deep Learning ...
# 797             720.0  A Google insider who anonymously leaked intern...
#
#       og:video:width  og:video:height  \
# 809           1280.0            720.0
# 560           1280.0            720.0
# 1045          1280.0            720.0
# 726           1280.0            720.0
# 891           1280.0            720.0
# 889           1280.0            720.0
# 779            640.0            360.0
# 1037          1280.0            720.0
# 984           1280.0            720.0
# 902           1280.0            720.0
# 563           1280.0            720.0
# 916           1280.0            720.0
# 975           1280.0            720.0
# 1099          1280.0            720.0
# 717           1280.0            720.0
# 725           1280.0            720.0
# 666           1280.0            720.0
# 1172          1280.0            720.0
# 570           1280.0            720.0
# 903           1280.0            720.0
# 739           1280.0            720.0
# 907           1280.0            720.0
# 1000          1280.0            720.0
# 776           1280.0            720.0
# 1098          1280.0            720.0
# 716           1280.0            720.0
# 944           1280.0            720.0
# 1165          1280.0            720.0
# 766           1280.0            720.0
# 668           1280.0            720.0
# 797           1280.0            720.0
#
#                                       og:video:tag  \
# 809   International Conference on Machine Learning
# 560                                 tableau course
# 1045                                           NaN
# 726                                      mrdbourke
# 891                         data science bootcamps
# 889                                  reading group
# 779                            100 days of ml code
# 1037                           data science course
# 984                                       computer
# 902                                  ai adventures
# 563                                            NaN
# 916                                            ЦФТ
# 975                        Artificial intelligence
# 1099                        Learn Machine Learning
# 717                                  reading group
# 725                                        QCon.ai
# 666                         reinforcement learning
# 1172                                     BOOTCAMPS
# 570                          home price prediction
# 903                                            NaN
# 739                        artificial intelligence
# 907                                speech commands
# 1000                                        python
# 776                                  reading group
# 1098                              trabalhar nubank
# 716                                          Tesla
# 944                                 Transportation
# 1165                                            CS
# 766                                             CS
# 668                                neural networks
# 797                                           leak
#
#                          channel_link_0  probability_liking_video
# 809   /channel/UC5g-f-g4EVRkqL8Xs888BLA                     0.219
# 560   /channel/UC8butISFwT-Wl7EV0hUK0BQ                     0.013
# 1045  /channel/UCK8sQmJBp8GCxrOtXWBpyEA                     0.142
# 726   /channel/UCr8O8l5cCX85Oem1d18EezQ                     0.051
# 891   /channel/UCn4Y0Ej7Vu3rO84e_aD28lg                     0.007
# 889   /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.056
# 779   /channel/UCr8O8l5cCX85Oem1d18EezQ                     0.141
# 1037  /channel/UCCktnahuRFYIBtNnKT5IYyg                     0.027
# 984   /channel/UCfzlCWGWYyIQ0aLC5w48gBQ                     0.005
# 902   /channel/UCJS9pqu9BzkAMNTmzNMNhvg                     0.114
# 563   /channel/UCT8VMsHASd47NEc2KrpbYvg                     0.090
# 916   /channel/UCv5Gi05tpsfPDbprgLeBGWA                     0.075
# 975   /channel/UCaMi9wzJ69KZQcRPJP-iz3w                     0.152
# 1099  /channel/UCNU_lfiiWBdtULKOw6X0Dig                     0.116
# 717   /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.055
# 725   /channel/UCkQX1tChV7Z7l1LFF4L9j_g                     0.209
# 666   /channel/UCCb9_Kn8F_Opb3UCGm-lILQ                     0.117
# 1172  /channel/UC68KSmHePPePCjW4v57VPQg                     0.030
# 570   /channel/UCRgTSWwZJn8AqkOmWuqD0wA                     0.108
# 903   /channel/UCyte7e0lLMQW3s4Oox-7rQQ                     0.076
# 739   /channel/UCo5DZgCa5n6Hzc0tIX_Ot7w                     0.167
# 907   /channel/UCvjgXvBlbQiydffZU7m1_aw                     0.176
# 1000  /channel/UCzr_QYwmGfXMkY2xOj7wPsQ                     0.239
# 776   /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.067
# 1098  /channel/UCgsDX3hTwiPdtGHJjMFfDxg                     0.021
# 716   /channel/UC4QZ_LsYcvcq7qOsOhpAX4A                     0.090
# 944   /channel/UCsT0YIqwnpJCM-mx7-gSA4Q                     0.078
# 1165  /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.025
# 766   /channel/UCSNeZleDn9c74yQc-EKnVTA                     0.118
# 668   /channel/UCotwjyJnb-4KW7bmsOoLfkg                     0.072
# 797   /channel/UCL9PlYkRD3Q-RZca6CCnPKw                     0.109
